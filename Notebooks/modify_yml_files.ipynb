# %%
sed 's/^\(description:\).*/\1MY LINE/' /Users/julia/bacterialGrowth_thesis/src/yml_info_files/study_information.yml
# Out:
# # New data to populate the DB
# # Substitute the null values with your data
# # Do not modify the indentation or remove any field, even if you do not have data for it
# STUDY:
# - NAME: null
#   STUDY_DESCRIPTION: null
# EXPERIMENT:
# - NAME:
#     value: null
#     description: Name of the experiment
#   REACTOR:
#     NAME:
#       value: null
#       description: Name of the reactor
#     VOLUME:
#       value: null
#       description: Volume in mL
#   PLATE:
#     ID:
#       value: null
#       description: Number of plate
#     COLUMN:
#       value: null
#       description: Indicated in numbers
#     ROW:
#       value: null
#       description: Indicated in numbers
#   MEDIA:
#     value: null
#     description: File path containing the media description
#   BACTERIA:
#   - SPECIES: null
#     STRAIN: null
#   - SPECIES: null
#     STRAIN: null
#   BLANK:
#     value: null
#     description: Boolean. True if the experiment is blank. False otherwise.
# ...

# %%
sed 's/^\(description:\).*/\1MY LINE/' /Users/julia/bacterialGrowth_thesis/src/yml_info_files/study_information.yml
# Out:
# # New data to populate the DB
# # Substitute the null values with your data
# # Do not modify the indentation or remove any field, even if you do not have data for it
# STUDY:
# - NAME: null
#   STUDY_DESCRIPTION: null
# EXPERIMENT:
# - NAME:
#     value: null
#     description: Name of the experiment
#   REACTOR:
#     NAME:
#       value: null
#       description: Name of the reactor
#     VOLUME:
#       value: null
#       description: Volume in mL
#   PLATE:
#     ID:
#       value: null
#       description: Number of plate
#     COLUMN:
#       value: null
#       description: Indicated in numbers
#     ROW:
#       value: null
#       description: Indicated in numbers
#   MEDIA:
#     value: null
#     description: File path containing the media description
#   BACTERIA:
#   - SPECIES: null
#     STRAIN: null
#   - SPECIES: null
#     STRAIN: null
#   BLANK:
#     value: null
#     description: Boolean. True if the experiment is blank. False otherwise.
# ...

# %%
ls -lt ../src/yml_info_files/
# Out:
# total 32
# -rw-r--r--  1 julia  staff  5204 31 mar 20:26 study_information.yml
# -rw-r--r--  1 julia  staff   229 31 mar 14:01 perturbation_information.yml
# -rw-r--r--  1 julia  staff   981 31 mar 14:00 experiment_information.yml

# %%
head ../src/yml_info_files/study_information.yml
# Out:
# # New data to populate the DB
# # Substitute the null values with your data
# # Do not modify the indentation or remove any field, even if you do not have data for it
# STUDY:
# - NAME: null
#   STUDY_DESCRIPTION: null
# EXPERIMENT:
# - NAME:
#     value: null
#     description: Name of the experiment

# %%
sed 's/description:/## description:/' /Users/julia/bacterialGrowth_thesis/src/yml_info_files/study_information.yml
# Out:
# # New data to populate the DB
# # Substitute the null values with your data
# # Do not modify the indentation or remove any field, even if you do not have data for it
# STUDY:
# - NAME: null
#   STUDY_DESCRIPTION: null
# EXPERIMENT:
# - NAME:
#     value: null
#     ## description: Name of the experiment
#   REACTOR:
#     NAME:
#       value: null
#       ## description: Name of the reactor
#     VOLUME:
#       value: null
#       ## description: Volume in mL
#   PLATE:
#     ID:
#       value: null
#       ## description: Number of plate
#     COLUMN:
#       value: null
#       ## description: Indicated in numbers
#     ROW:
#       value: null
#       ## description: Indicated in numbers
#   MEDIA:
#     value: null
#     ## description: File path containing the media description
#   BACTERIA:
#   - SPECIES: null
#     STRAIN: null
#   - SPECIES: null
#     STRAIN: null
#   BLANK:
#     value: null
#     ## description: Boolean. True if the experiment is blank. False otherwise.
# ...

# %%
sed 's/description:/## description:/' /Users/julia/bacterialGrowth_thesis/src/yml_info_files/study_information.yml > hola.yml

# %%
ls -lt
# Out:
# total 672
# -rw-r--r--  1 julia  staff    5369 31 mar 20:27 hola.yml
# -rw-r--r--  1 julia  staff   17842 31 mar 20:25 Untitled.ipynb
# -rw-r--r--  1 julia  staff   16243 31 mar 20:11 yaml_functions.ipynb
# -rw-r--r--  1 julia  staff   17923 30 mar 12:22 add_replicates_files.ipynb
# -rw-r--r--  1 julia  staff  112004 23 mar 11:47 filepath_plots_2.ipynb
# -rw-r--r--  1 julia  staff   81079 23 mar 11:37 filepath_plots.ipynb
# -rw-r--r--  1 julia  staff   10842 17 mar 13:01 add_experiment.ipynb
# -rw-r--r--  1 julia  staff   13255 17 mar 11:56 lab_files_analysis_2.ipynb
# -rw-r--r--  1 julia  staff   39497 13 mar 12:37 filepath_add_replicates_files.ipynb
# -rw-r--r--  1 julia  staff    9945  9 mar 16:29 lab_files_analysis.ipynb

# %%
head hola.yml
# Out:
# # New data to populate the DB
# # Substitute the null values with your data
# # Do not modify the indentation or remove any field, even if you do not have data for it
# STUDY:
# - NAME: null
#   STUDY_DESCRIPTION: null
# EXPERIMENT:
# - NAME:
#     value: null
#     ## description: Name of the experiment

# %%
cp /Users/julia/bacterialGrowth_thesis/src/yml_info_files/study_information.yml test.yml

# %%
sed 's/STUDY:/\n\nSTUDY:/' test.yml
# Out:
# # New data to populate the DB
# # Substitute the null values with your data
# # Do not modify the indentation or remove any field, even if you do not have data for it
#
#
# STUDY:
# - NAME: null
#   STUDY_DESCRIPTION: null
# EXPERIMENT:
# - NAME:
#     value: null
#     description: Name of the experiment
#   REACTOR:
#     NAME:
#       value: null
#       description: Name of the reactor
#     VOLUME:
#       value: null
#       description: Volume in mL
#   PLATE:
#     ID:
#       value: null
#       description: Number of plate
#     COLUMN:
#       value: null
#       description: Indicated in numbers
#     ROW:
#       value: null
#       description: Indicated in numbers
#   MEDIA:
#     value: null
#     description: File path containing the media description
#   BACTERIA:
#   - SPECIES: null
#     STRAIN: null
#   - SPECIES: null
#     STRAIN: null
#   BLANK:
#     value: null
#     description: Boolean. True if the experiment is blank. False otherwise.
# ...

# %%
#sed 's/STUDY:/\n\nSTUDY:/' test.yml > test_tmp.yml

# %%
sed 's/STUDY:/\n\nSTUDY:/' test.yml > test_tmp.yml
cp test_tmp.yml test.yml

# %%
sed 's/STUDY:/\n\nSTUDY:/' test.yml > test_tmp.yml
cp test_tmp.yml test.yml
sed 's/EXPERIMENT:/\n\nEXPERIMENT:/' test.yml > test_tmp.yml
cp test_tmp.yml test.yml
sed 's/PERTURBATION:/\n\PERTURBATION:/' test.yml > test_tmp.yml
cp test_tmp.yml test.yml
sed 's/FILES:/\n\nFILES:/' test.yml > test_tmp.yml
cp test_tmp.yml test.yml

# %%
head test_tmp.yml
# Out:
# # New data to populate the DB
# # Substitute the null values with your data
# # Do not modify the indentation or remove any field, even if you do not have data for it
#
#
# STUDY:
# - NAME: null
#   STUDY_DESCRIPTION: null
# EXPERIMENT:
# - NAME:
#     value: null
#     description: Name of the experiment
#   REACTOR:
#     NAME:
#       value: null
#       description: Name of the reactor
#     VOLUME:
#       value: null
#       description: Volume in mL
#   PLATE:
#     ID:
#       value: null
# >mp.yml

# %%
head test.yml
# Out:
# # New data to populate the DB
# # Substitute the null values with your data
# # Do not modify the indentation or remove any field, even if you do not have data for it
# STUDY:
# - NAME: null
#   STUDY_DESCRIPTION: null
# EXPERIMENT:
# - NAME:
#     value: null
#     description: Name of the experiment

# %%
cp /Users/julia/bacterialGrowth_thesis/src/yml_info_files/study_information.yml test.yml

# %%
sed 's/description:/## description:/' test.yml | \
    sed 's/STUDY:/\n\nSTUDY:/' | \
    sed 's/EXPERIMENT:/\n\nEXPERIMENT:/' | \
    sed 's/PERTURBATION:/\n\PERTURBATION:/' | \
    sed 's/FILES:/\n\nFILES:/' > test_tmp.yml

# %%
head test.yml
# Out:
# # New data to populate the DB
# # Substitute the null values with your data
# # Do not modify the indentation or remove any field, even if you do not have data for it
# STUDY:
# - NAME: null
#   STUDY_DESCRIPTION: null
# EXPERIMENT:
# - NAME:
#     value: null
#     description: Name of the experiment

# %%
tail test_tmp.yml
# Out:
#       ## description: Time in minutes
#     DESCRIPTION:
#       value: null
#       ## description: Description of the perturbation
#
#
# FILES:
#       value: null
#       ## description: Directory with the files corresponding to this perturbation. One
#         file per technical replicate.
